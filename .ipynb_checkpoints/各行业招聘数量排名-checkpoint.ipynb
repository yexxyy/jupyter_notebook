# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def get_conn():
	engine = create_engine('mysql://root:123456@localhost:3306/zhilian?charset=utf8', echo=False)
	conn = engine.connect()
	return conn

conn = get_conn()

#统计不同行业中招聘岗位的数量

#公司数据
com_industry_sql="""
    SELECT com_md5,com_industry FROM zhilian_company
"""
industry_data=pd.read_sql(com_industry_sql, conn)
industry_data.tail()
# Out:
#                                 com_md5        com_industry
# 76064  fffe754783e0cdb5af279aedde59d9f5       电子技术/半导体/集成电路
# 76065  fffef0b0260cc3e64fbb5a46e4fc0694  快速消费品（食品/饮料/烟酒/日化）
# 76066  ffff349adef75ed6a9bffcc64059da16            互联网/电子商务
# 76067  ffff5e817d44e50ce6f5ea632d66cbea        家居/室内设计/装饰装潢
# 76068  ffffd8d811735b8d797a8eeffb816016         基金/证券/期货/投资

# %%
#岗位数据
job_recruit_num_sql="""
    SELECT com_md5,recruit_num FROM zhilian_job
"""
recruit_num_data=pd.read_sql(job_recruit_num_sql,conn)
recruit_num_data.tail()
# Out:
#                                  com_md5  recruit_num
# 397657  1dab898477a2166b8b809e84ba688df9            1
# 397658  906f63badb9d83f15174997d2bcc26a3            2
# 397659  177428efcaaacd0815ec973671f2fc73            2
# 397660  15d2adbd4f8cedd2f353078fff692617            2
# 397661  c1120ff3a53fbfd077627424e8188724           10

# %%
#合并数据
merge_res=pd.merge(recruit_num_data,industry_data,on='com_md5')
res_grouped=merge_res.groupby('com_industry')
output=res_grouped.sum().sort_values(by='recruit_num',ascending=False)
output
# Out:
#                        recruit_num
# com_industry
# 互联网/电子商务                    360782
# 房地产/建筑/建材/工程                287202
# 教育/培训/院校                    189965
# 快速消费品（食品/饮料/烟酒/日化）          154668
# 医药/生物工程                     113427
# 基金/证券/期货/投资                 105683
# 专业服务/咨询(财会/法律/人力资源等)         97145
# 计算机软件                        95527
# 酒店/餐饮                        73125
# 信托/担保/拍卖/典当                  59568
# 加工制造（原料加工/模具）                58821
# 电子技术/半导体/集成电路                58572
# IT服务(系统/数据/维护)               56405
# 媒体/出版/影视/文化传播                52087
# 交通/运输                        46158
# 汽车/摩托车                       46139
# 大型设备/机电设备/重工业                44616
# 零售/批发                        44312
# 家居/室内设计/装饰装潢                 43811
# 贸易/进出口                       38127
# 保险                           35137
# 农/林/牧/渔                      34108
# 医疗/护理/美容/保健/卫生服务             33984
# 耐用消费品（服饰/纺织/皮革/家具/家电）        32711
# 物流/仓储                        26247
# 仪器仪表及工业自动化                   25524
# 广告/会展/公关                     25315
# 能源/矿产/采掘/冶炼                  23696
# 通信/电信运营、增值服务                 22114
# 中介服务                         21786
# 石油/石化/化工                     20213
# 外包服务                         19463
# 医疗设备/器械                      18752
# 通信/电信/网络设备                   18640
# 计算机硬件                        17928
# 银行                           17143
# 环保                           16421
# 其他                           15663
# 物业管理/商业中心                    14892
# 旅游/度假                        14117
# 电气/电力/水利                     12094
# 娱乐/体育/休闲                     11483
# 网络游戏                          9552
# 礼品/玩具/工艺美术/收藏品/奢侈品            8565
# 学术/科研                         7718
# 租赁服务                          7518
# 政府/公共事业/非盈利机构                 5119
# 检验/检测/认证                      5116
# 印刷/包装/造纸                      4421
# 跨领域经营                         3320
# 办公用品及设备                       2487
# 航空/航天研究与制造                    2210

# %%
#绘制条状图
fig,ax=plt.subplots()

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

#设置背景
#print(plt.style.available)
#['_classic_test', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2']
# plt.style.use('seaborn-white')

#加载数据
plt.barh(output.index,output['recruit_num'])
# output.plot()

#设置lable旋转
labels=ax.get_xticklabels()
plt.setp(labels,rotation=45,horizontalalignment='right')

#设置标题等
ax.set(xlabel='招聘人数', ylabel='行业',
   title='各行业招聘人数排名')
#添加平均线
ax.axvline(output.mean().values,ls='--',color='r')

plt.show()
