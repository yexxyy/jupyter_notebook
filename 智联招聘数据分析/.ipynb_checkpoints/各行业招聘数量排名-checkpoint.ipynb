# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def get_conn():
	engine = create_engine('mysql://root:123456@localhost:3306/zhilian?charset=utf8', echo=False)
	conn = engine.connect()
	return conn

conn = get_conn()

#统计不同行业中招聘岗位的数量

#公司数据
com_industry_sql="""
    SELECT com_md5,com_industry FROM zhilian_company
"""
industry_data=pd.read_sql(com_industry_sql, conn)
industry_data.tail()
# Out:
#                                 com_md5        com_industry
# 76261  fffe754783e0cdb5af279aedde59d9f5       电子技术/半导体/集成电路
# 76262  fffef0b0260cc3e64fbb5a46e4fc0694  快速消费品（食品/饮料/烟酒/日化）
# 76263  ffff349adef75ed6a9bffcc64059da16            互联网/电子商务
# 76264  ffff5e817d44e50ce6f5ea632d66cbea        家居/室内设计/装饰装潢
# 76265  ffffd8d811735b8d797a8eeffb816016         基金/证券/期货/投资

# %%
#岗位数据
job_recruit_num_sql="""
    SELECT com_md5,recruit_num FROM zhilian_job
"""
recruit_num_data=pd.read_sql(job_recruit_num_sql,conn)
recruit_num_data.tail()
# Out:
#                                  com_md5  recruit_num
# 398748  f638ed7185c723109159acf6effe0703          999
# 398749  958554fb2d6a8d039878c0bdd8035129            1
# 398750  493c8a62edbc647e83c26bcc43996bea            1
# 398751  8d3f7f06da9423a0be51964bd09f5635            1
# 398752  66b723c36ad1742a2cd480ca97f68bcd            1

# %%
#合并数据
merge_res=pd.merge(recruit_num_data,industry_data,on='com_md5')
res_grouped=merge_res.groupby('com_industry')
output=res_grouped.sum().sort_values(by='recruit_num',ascending=False)
output
# Out:
#                        recruit_num
# com_industry
# 互联网/电子商务                    361453
# 房地产/建筑/建材/工程                287712
# 教育/培训/院校                    190600
# 快速消费品（食品/饮料/烟酒/日化）          154986
# 医药/生物工程                     114671
# 基金/证券/期货/投资                 105772
# 专业服务/咨询(财会/法律/人力资源等)         97265
# 计算机软件                        95584
# 酒店/餐饮                        73169
# 信托/担保/拍卖/典当                  59568
# 加工制造（原料加工/模具）                59045
# 电子技术/半导体/集成电路                58636
# IT服务(系统/数据/维护)               56452
# 媒体/出版/影视/文化传播                52142
# 交通/运输                        46292
# 汽车/摩托车                       46270
# 大型设备/机电设备/重工业                44684
# 零售/批发                        44344
# 家居/室内设计/装饰装潢                 43855
# 贸易/进出口                       38218
# 保险                           35217
# 农/林/牧/渔                      34178
# 医疗/护理/美容/保健/卫生服务             34043
# 耐用消费品（服饰/纺织/皮革/家具/家电）        32801
# 物流/仓储                        26274
# 仪器仪表及工业自动化                   25554
# 广告/会展/公关                     25355
# 能源/矿产/采掘/冶炼                  23702
# 通信/电信运营、增值服务                 22149
# 中介服务                         21839
# 石油/石化/化工                     20285
# 外包服务                         19784
# 医疗设备/器械                      18856
# 通信/电信/网络设备                   18643
# 计算机硬件                        17938
# 银行                           17162
# 环保                           16579
# 其他                           15694
# 物业管理/商业中心                    15051
# 旅游/度假                        14144
# 电气/电力/水利                     12240
# 娱乐/体育/休闲                     11495
# 网络游戏                          9582
# 礼品/玩具/工艺美术/收藏品/奢侈品            8578
# 学术/科研                         7805
# 租赁服务                          7518
# 检验/检测/认证                      5155
# 政府/公共事业/非盈利机构                 5121
# 印刷/包装/造纸                      4436
# 跨领域经营                         3324
# 办公用品及设备                       2487
# 航空/航天研究与制造                    2210

# %%
#预览数据
#output.plot()

#绘制条状图
fig,ax=plt.subplots(figsize=(8, 12))

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

#设置背景
#print(plt.style.available)
#['_classic_test', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2']
# plt.style.use('seaborn-white')

#加载数据
plt.barh(output.index,output['recruit_num'])

#设置lable旋转
labels=ax.get_xticklabels()
plt.setp(labels,rotation=45,horizontalalignment='right')

#设置标题等
ax.set(xlabel='招聘人数', ylabel='行业',
   title='各行业招聘人数排名')
#添加平均线
ax.axvline(output.mean().values,ls='--',color='r')

plt.show() 

#保存图片
# print(fig.canvas.get_supported_filetypes())
fig.savefig('{}.png'.format(ax.get_title()), transparent=False, dpi=80, bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
#     123     bytes_io = BytesIO()
# --> 124     fig.canvas.print_figure(bytes_io, **kw)
#     125     data = bytes_io.getvalue()
#     126     if fmt == 'svg':
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2206                     orientation=orientation,
#    2207                     dryrun=True,
# -> 2208                     **kwargs)
#    2209                 renderer = self.figure._cachedRenderer
#    2210                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             if toolbar:
#     429                 toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             if toolbar:
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1293
#    1294             mimage._draw_list_compositing_images(
# -> 1295                 renderer, self, artists, self.suppressComposite)
#    1296
#    1297             renderer.close_group('figure')
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2397             renderer.stop_rasterizing()
#    2398
# -> 2399         mimage._draw_list_compositing_images(renderer, self, artists)
#    2400
#    2401         renderer.close_group('axes')
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/text.py in draw(self, renderer)
#     753
#     754         with _wrap_text(self) as textobj:
# --> 755             bbox, info, descent = textobj._get_layout(renderer)
#     756             trans = textobj.get_transform()
#     757
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     334         of a rotated text when necessary.
#     335         """
# --> 336         key = self.get_prop_tup(renderer=renderer)
#     337         if key in self._cached:
#     338             return self._cached[key]
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/text.py in get_prop_tup(self, renderer)
#     908         need to know if the text has changed.
#     909         """
# --> 910         x, y = self.get_unitless_position()
#     911         renderer = renderer or self._renderer
#     912         return (x, y, self.get_text(), self._color,
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/text.py in get_unitless_position(self)
#     890         # This will get the position with all unit information stripped away.
#     891         # This is here for convienience since it is done in several locations.
# --> 892         x = float(self.convert_xunits(self._x))
#     893         y = float(self.convert_yunits(self._y))
#     894         return x, y
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     189         if ax is None or ax.xaxis is None:
#     190             return x
# --> 191         return ax.xaxis.convert_units(x)
#     192
#     193     def convert_yunits(self, y):
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1489             return x
#    1490
# -> 1491         ret = self.converter.convert(x, self.units, self)
#    1492         return ret
#    1493
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      41         data as floats
#      42         """
# ---> 43         vmap = dict(zip(axis.unit_data.seq, axis.unit_data.locs))
#      44
#      45         if isinstance(value, six.string_types):
#
# AttributeError: 'NoneType' object has no attribute 'seq'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-cfab9919045e> in <module>()
#      34 #保存图片
#      35 # print(fig.canvas.get_supported_filetypes())
# ---> 36 fig.savefig('{}.png'.format(ax.get_title()), transparent=False, dpi=80, bbox_inches="tight")
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    1812             self.set_frameon(frameon)
#    1813
# -> 1814         self.canvas.print_figure(fname, **kwargs)
#    1815
#    1816         if frameon:
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2206                     orientation=orientation,
#    2207                     dryrun=True,
# -> 2208                     **kwargs)
#    2209                 renderer = self.figure._cachedRenderer
#    2210                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             if toolbar:
#     429                 toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             if toolbar:
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1293
#    1294             mimage._draw_list_compositing_images(
# -> 1295                 renderer, self, artists, self.suppressComposite)
#    1296
#    1297             renderer.close_group('figure')
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2397             renderer.stop_rasterizing()
#    2398
# -> 2399         mimage._draw_list_compositing_images(renderer, self, artists)
#    2400
#    2401         renderer.close_group('axes')
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/patches.py in draw(self, renderer)
#     564
#     565         path = self.get_path()
# --> 566         transform = self.get_transform()
#     567         tpath = transform.transform_path_non_affine(path)
#     568         affine = transform.get_affine()
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/patches.py in get_transform(self)
#     219         to the :class:`Patch`.
#     220         """
# --> 221         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     222
#     223     def get_data_transform(self):
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     720
#     721     def get_patch_transform(self):
# --> 722         self._update_patch_transform()
#     723         return self._rect_transform
#     724
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/patches.py in _update_patch_transform(self)
#     709                  not directly access the transformation member variable.
#     710         """
# --> 711         x = self.convert_xunits(self._x)
#     712         y = self.convert_yunits(self._y)
#     713         width = self.convert_xunits(self._width)
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     189         if ax is None or ax.xaxis is None:
#     190             return x
# --> 191         return ax.xaxis.convert_units(x)
#     192
#     193     def convert_yunits(self, y):
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1489             return x
#    1490
# -> 1491         ret = self.converter.convert(x, self.units, self)
#    1492         return ret
#    1493
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      41         data as floats
#      42         """
# ---> 43         vmap = dict(zip(axis.unit_data.seq, axis.unit_data.locs))
#      44
#      45         if isinstance(value, six.string_types):
#
# AttributeError: 'NoneType' object has no attribute 'seq'
