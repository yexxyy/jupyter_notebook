# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def get_conn():
	engine = create_engine('mysql://root:123456@localhost:3306/zhilian?charset=utf8', echo=False)
	conn = engine.connect()
	return conn

conn = get_conn()

#统计不同行业中招聘岗位的数量

#公司数据
com_industry_sql="""
    SELECT com_md5,com_industry FROM zhilian_company
"""
industry_data=pd.read_sql(com_industry_sql, conn)
industry_data.tail()
# Out:
#                                 com_md5        com_industry
# 76261  fffe754783e0cdb5af279aedde59d9f5       电子技术/半导体/集成电路
# 76262  fffef0b0260cc3e64fbb5a46e4fc0694  快速消费品（食品/饮料/烟酒/日化）
# 76263  ffff349adef75ed6a9bffcc64059da16            互联网/电子商务
# 76264  ffff5e817d44e50ce6f5ea632d66cbea        家居/室内设计/装饰装潢
# 76265  ffffd8d811735b8d797a8eeffb816016         基金/证券/期货/投资

# %%
#岗位数据
job_recruit_num_sql="""
    SELECT com_md5,recruit_num FROM zhilian_job
"""
recruit_num_data=pd.read_sql(job_recruit_num_sql,conn)
recruit_num_data.tail()
# Out:
#                                  com_md5  recruit_num
# 398748  f638ed7185c723109159acf6effe0703          999
# 398749  958554fb2d6a8d039878c0bdd8035129            1
# 398750  493c8a62edbc647e83c26bcc43996bea            1
# 398751  8d3f7f06da9423a0be51964bd09f5635            1
# 398752  66b723c36ad1742a2cd480ca97f68bcd            1

# %%
#合并数据
merge_res=pd.merge(recruit_num_data,industry_data,on='com_md5')
res_grouped=merge_res.groupby('com_industry')
output=res_grouped.sum().sort_values(by='recruit_num',ascending=False)
output
# Out:
#                        recruit_num
# com_industry
# 互联网/电子商务                    361453
# 房地产/建筑/建材/工程                287712
# 教育/培训/院校                    190600
# 快速消费品（食品/饮料/烟酒/日化）          154986
# 医药/生物工程                     114671
# 基金/证券/期货/投资                 105772
# 专业服务/咨询(财会/法律/人力资源等)         97265
# 计算机软件                        95584
# 酒店/餐饮                        73169
# 信托/担保/拍卖/典当                  59568
# 加工制造（原料加工/模具）                59045
# 电子技术/半导体/集成电路                58636
# IT服务(系统/数据/维护)               56452
# 媒体/出版/影视/文化传播                52142
# 交通/运输                        46292
# 汽车/摩托车                       46270
# 大型设备/机电设备/重工业                44684
# 零售/批发                        44344
# 家居/室内设计/装饰装潢                 43855
# 贸易/进出口                       38218
# 保险                           35217
# 农/林/牧/渔                      34178
# 医疗/护理/美容/保健/卫生服务             34043
# 耐用消费品（服饰/纺织/皮革/家具/家电）        32801
# 物流/仓储                        26274
# 仪器仪表及工业自动化                   25554
# 广告/会展/公关                     25355
# 能源/矿产/采掘/冶炼                  23702
# 通信/电信运营、增值服务                 22149
# 中介服务                         21839
# 石油/石化/化工                     20285
# 外包服务                         19784
# 医疗设备/器械                      18856
# 通信/电信/网络设备                   18643
# 计算机硬件                        17938
# 银行                           17162
# 环保                           16579
# 其他                           15694
# 物业管理/商业中心                    15051
# 旅游/度假                        14144
# 电气/电力/水利                     12240
# 娱乐/体育/休闲                     11495
# 网络游戏                          9582
# 礼品/玩具/工艺美术/收藏品/奢侈品            8578
# 学术/科研                         7805
# 租赁服务                          7518
# 检验/检测/认证                      5155
# 政府/公共事业/非盈利机构                 5121
# 印刷/包装/造纸                      4436
# 跨领域经营                         3324
# 办公用品及设备                       2487
# 航空/航天研究与制造                    2210

# %%
#预览数据
#output.plot()

#绘制条状图
fig,ax=plt.subplots(figsize=(8, 12))

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

#设置背景
#print(plt.style.available)
#['_classic_test', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2']
# plt.style.use('seaborn-white')

#加载数据
plt.barh(output.index,output['recruit_num'])

#设置lable旋转
labels=ax.get_xticklabels()
plt.setp(labels,rotation=45,horizontalalignment='right')

#设置标题等
ax.set(xlabel='招聘人数', ylabel='行业',
   title='各行业招聘人数排名')
#添加平均线
ax.axvline(output.mean().values,ls='--',color='r')

print(output.vaues)
# for index,num in output.values:
# #     ax.text(num, output.index, num, fontsize=10,verticalalignment="center")
#     print(index,num)
    
plt.show() 

#保存图片
# print(fig.canvas.get_supported_filetypes())
fig.savefig('{}.png'.format(ax.get_title()), transparent=False, dpi=80, bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-95c942368e08> in <module>()
#      27 ax.axvline(output.mean().values,ls='--',color='r')
#      28
# ---> 29 print(output.vaues)
#      30 # for index,num in output.values:
#      31 # #     ax.text(num, output.index, num, fontsize=10,verticalalignment="center")
#
# /Users/yexianyong/Library/Python/3.6/lib/python/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'vaues'
