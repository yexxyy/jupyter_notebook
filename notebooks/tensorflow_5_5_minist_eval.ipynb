# %%
import time
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

#加载inference、train中的常量
import ipynb_importer
import tensorflow_5_5_mnist_train as mnist_train
import tensorflow_5_5_mnist_inference as mnist_inference

#每10秒加载一次最新的模型，并在测试数据上测试正确率
EVAL_INTERVAL_SECS=10

def evaluate(mnist):
    with tf.Graph().as_default() as g:
        x=tf.placeholder(tf.float32,[None,mnist_inference.INPUT_NODE],name='x-input')
        y_=tf.placeholder(tf.float32,[None,mnist_inference.OUTPUT_NODE],name='y-input')
        
        validate_feed={x:mnist.validation.images,y_:mnist.validation.labels}
        
        y=mnist_inference.inference(x,None)
        correct_prediction=tf.equal(tf.argmax(y,1),tf.argmax(y_,1))
        accuracy=tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
        
        #通过变量重命名方式来加载模型，这样在向前传播的过程中就不需要调用求滑动平均的函数来获取平均值了。
        #这样就可以完全共用mnist_inference中定义的向前传播inference函数
        variable_averages=tf.train.ExponentialMovingAverage(mnist_train.MOVING_AVERAGE_DECAY)
        variables_to_restore=variable_averages.variables_to_restore()
        saver=tf.train.Saver(variables_to_restore)
        
        while True:
            with tf.Session() as sess:
                #tf.train.get_checkpoint_state会通过checkpoint文件自动找到目录中最新的文件名
                ckpt=tf.train.get_checkpoint_state(mnist_train.MODEL_SAVE_PATH)
                if ckpt and ckpt.model_checkpoint_path:
                    #加载模型
                    saver.restore(sess,ckpt.model_checkpoint_path)
                    #通过文件名得到模型保存是迭代的轮数
                    global_step=ckpt.model_checkpoint_path.split('/')[-1].split('-')[-1]
                    accuracy_score=sess.run(accuracy,feed_dict=validate_feed)
                    
                    print 'After %s training steps,accuracy=%f' % (global_step,accuracy_score)
                else:
                    print 'No checkpoint file found'

                time.sleep(EVAL_INTERVAL_SECS)
                    
def main(argv=None):
    mnist=input_data.read_data_sets('.MNIST_data',one_hot=True)
    evaluate(mnist)
    
if __name__=='__main__':
    tf.app.run()

# %% [raw]
# Extracting .MNIST_data/train-images-idx3-ubyte.gz
# Extracting .MNIST_data/train-labels-idx1-ubyte.gz
# Extracting .MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting .MNIST_data/t10k-labels-idx1-ubyte.gz
# No checkpoint file found
# No checkpoint file found
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-1
# After 1 training steps,accuracy=0.130600
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-1
# After 1 training steps,accuracy=0.130600
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-1001
# After 1001 training steps,accuracy=0.977400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-2001
# After 2001 training steps,accuracy=0.980400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-3001
# After 3001 training steps,accuracy=0.980600
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-4001
# After 4001 training steps,accuracy=0.983000
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-5001
# After 5001 training steps,accuracy=0.982000
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-6001
# After 6001 training steps,accuracy=0.982800
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-6001
# After 6001 training steps,accuracy=0.982800
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-7001
# After 7001 training steps,accuracy=0.983400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-8001
# After 8001 training steps,accuracy=0.983400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-9001
# After 9001 training steps,accuracy=0.983800
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-10001
# After 10001 training steps,accuracy=0.984000
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-11001
# After 11001 training steps,accuracy=0.984200
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-12001
# After 12001 training steps,accuracy=0.984200
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-13001
# After 13001 training steps,accuracy=0.984400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-14001
# After 14001 training steps,accuracy=0.984600
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-15001
# After 15001 training steps,accuracy=0.985600
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-16001
# After 16001 training steps,accuracy=0.984600
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-17001
# After 17001 training steps,accuracy=0.985200
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-18001
# After 18001 training steps,accuracy=0.983800
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-19001
# After 19001 training steps,accuracy=0.983400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-19001
# After 19001 training steps,accuracy=0.983400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-20001
# After 20001 training steps,accuracy=0.983800
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-21001
# After 21001 training steps,accuracy=0.983800
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-22001
# After 22001 training steps,accuracy=0.983400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-23001
# After 23001 training steps,accuracy=0.984400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-24001
# After 24001 training steps,accuracy=0.983600
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-24001
# After 24001 training steps,accuracy=0.983600
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-25001
# After 25001 training steps,accuracy=0.983400
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-26001
# After 26001 training steps,accuracy=0.984000
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-27001
# After 27001 training steps,accuracy=0.983800
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-28001
# After 28001 training steps,accuracy=0.986000
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-29001
# After 29001 training steps,accuracy=0.984200
# INFO:tensorflow:Restoring parameters from ./tmp/best_example/model.ckpt-29001
# After 29001 training steps,accuracy=0.984200
